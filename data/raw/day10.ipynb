# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\LENOVO\Documents\Internship\sessions.csv")

# %%
df["session_start"] = pd.to_datetime(df["session_start"])
df["session_end"] = pd.to_datetime(df["session_end"])

# %%
df["session_length_minutes"] = (
    df["session_end"] - df["session_start"]
).dt.total_seconds() / 60

print(df)
# Out:
#    user_id       session_start         session_end  session_length_minutes
# 0     U001 2026-06-01 09:00:00 2026-06-01 09:18:00                    18.0
# 1     U002 2026-06-01 09:05:00 2026-06-01 09:42:00                    37.0
# 2     U003 2026-06-01 10:10:00 2026-06-01 10:25:00                    15.0
# 3     U004 2026-06-01 10:30:00 2026-06-01 11:15:00                    45.0
# 4     U005 2026-06-01 11:00:00 2026-06-01 11:08:00                     8.0
# 5     U001 2026-06-02 09:20:00 2026-06-02 09:55:00                    35.0
# 6     U002 2026-06-02 10:15:00 2026-06-02 10:45:00                    30.0
# 7     U003 2026-06-02 11:05:00 2026-06-02 11:50:00                    45.0
# 8     U004 2026-06-02 12:00:00 2026-06-02 12:12:00                    12.0
# 9     U005 2026-06-02 13:10:00 2026-06-02 14:05:00                    55.0
# 10    U001 2026-06-03 09:00:00 2026-06-03 09:10:00                    10.0
# 11    U002 2026-06-03 09:30:00 2026-06-03 10:20:00                    50.0
# 12    U003 2026-06-03 10:45:00 2026-06-03 11:05:00                    20.0
# 13    U004 2026-06-03 14:00:00 2026-06-03 15:30:00                    90.0
# 14    U005 2026-06-03 15:15:00 2026-06-03 15:40:00                    25.0
# 15    U001 2026-06-04 08:50:00 2026-06-04 09:35:00                    45.0
# 16    U002 2026-06-04 10:00:00 2026-06-04 10:05:00                     5.0
# 17    U003 2026-06-04 11:20:00 2026-06-04 12:10:00                    50.0
# 18    U004 2026-06-04 13:00:00 2026-06-04 13:25:00                    25.0
# 19    U005 2026-06-04 16:00:00 2026-06-04 17:20:00                    80.0

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10,6))

plt.hist(
    df["session_length_minutes"],
    bins=50
)

plt.xlabel("Session Length (minutes)")
plt.ylabel("Number of Sessions")
plt.title("Session Length Distribution")
# Out:
# Text(0.5, 1.0, 'Session Length Distribution')

# %%
plt.show()
